# %% [markdown]
# ## Importing pandas

# %%
import pandas as pd
#Let's also import numpy
import numpy as np

# %% [markdown]
# ### Reading csvs

# %%
df=pd.read_csv('/Data/csvs/gapminder_tidy.csv')

# %% [markdown]
# ### Displaying top 5 rows

# %%
df.head(5)
# Out:
#        Country  Year  fertility    life  population  child_mortality     gdp  \
# 0  Afghanistan  1964      7.671  33.639  10474903.0            339.7  1182.0
# 1  Afghanistan  1965      7.671  34.152  10697983.0            334.1  1182.0
# 2  Afghanistan  1966      7.671  34.662  10927724.0            328.7  1168.0
# 3  Afghanistan  1967      7.671  35.170  11163656.0            323.3  1173.0
# 4  Afghanistan  1968      7.671  35.674  11411022.0            318.1  1187.0
#
#        region
# 0  South Asia
# 1  South Asia
# 2  South Asia
# 3  South Asia
# 4  South Asia

# %% [markdown]
# ### Displaying last 5 rows

# %%
df.tail(5)
# Out:
#       Country  Year  fertility   life  population  child_mortality  gdp  \
# 10106   Åland  2002        NaN  81.80     26257.0              NaN  NaN
# 10107   Åland  2003        NaN  80.63     26347.0              NaN  NaN
# 10108   Åland  2004        NaN  79.88     26530.0              NaN  NaN
# 10109   Åland  2005        NaN  80.00     26766.0              NaN  NaN
# 10110   Åland  2006        NaN  80.10     26923.0              NaN  NaN
#
#                       region
# 10106  Europe & Central Asia
# 10107  Europe & Central Asia
# 10108  Europe & Central Asia
# 10109  Europe & Central Asia
# 10110  Europe & Central Asia

# %% [markdown]
# ### Info/Summary and other properties of a Dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10111 entries, 0 to 10110
# Data columns (total 8 columns):
# Country            10111 non-null object
# Year               10111 non-null int64
# fertility          10100 non-null float64
# life               10111 non-null float64
# population         10108 non-null float64
# child_mortality    9210 non-null float64
# gdp                9000 non-null float64
# region             10111 non-null object
# dtypes: float64(5), int64(1), object(2)
# memory usage: 632.0+ KB

# %%
df.describe()
# Out:
#                Year     fertility          life    population  \
# count  10111.000000  10100.000000  10111.000000  1.010800e+04
# mean    1988.514588      4.028719     64.078600  2.560448e+07
# std       14.430849      2.013968     11.122779  1.032383e+08
# min     1964.000000      0.836000      6.000000  1.170000e+03
# 25%     1976.000000      2.175750     56.282500  8.874062e+05
# 50%     1989.000000      3.632500     67.157000  4.765781e+06
# 75%     2001.000000      5.905250     72.484000  1.476995e+07
# max     2013.000000      9.223000     83.580000  1.359368e+09
#
#        child_mortality            gdp
# count      9210.000000    9000.000000
# mean         80.834505   12746.916667
# std          79.220942   17797.809953
# min           2.000000     142.000000
# 25%          18.900000    2263.000000
# 50%          50.700000    6438.500000
# 75%         121.775000   15887.250000
# max         435.800000  182668.000000

# %%
df.shape
# Out:
# (10111, 8)

# %% [markdown]
# ### Printing the columns name

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'fertility', 'life', 'population', 'child_mortality',
#        'gdp', 'region'],
#       dtype='object')

# %% [markdown]
# ### Indexing of columns

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10111, step=1)

# %% [markdown]
# ### Accessing dataframe data/elements

# %%
#Accessing column by name

# %%
df['Country']
# Out:
# 0        Afghanistan
# 1        Afghanistan
# 2        Afghanistan
# 3        Afghanistan
# 4        Afghanistan
# 5        Afghanistan
# 6        Afghanistan
# 7        Afghanistan
# 8        Afghanistan
# 9        Afghanistan
# 10       Afghanistan
# 11       Afghanistan
# 12       Afghanistan
# 13       Afghanistan
# 14       Afghanistan
# 15       Afghanistan
# 16       Afghanistan
# 17       Afghanistan
# 18       Afghanistan
# 19       Afghanistan
# 20       Afghanistan
# 21       Afghanistan
# 22       Afghanistan
# 23       Afghanistan
# 24       Afghanistan
# 25       Afghanistan
# 26       Afghanistan
# 27       Afghanistan
# 28       Afghanistan
# 29       Afghanistan
#             ...
# 10081       Zimbabwe
# 10082       Zimbabwe
# 10083       Zimbabwe
# 10084       Zimbabwe
# 10085       Zimbabwe
# 10086       Zimbabwe
# 10087       Zimbabwe
# 10088       Zimbabwe
# 10089       Zimbabwe
# 10090       Zimbabwe
# 10091       Zimbabwe
# 10092       Zimbabwe
# ...

# %% [markdown]
# ### Accessing multiple columns

# %%
df[['Country', 'Year', 'fertility']]
# Out:
#            Country  Year  fertility
# 0      Afghanistan  1964      7.671
# 1      Afghanistan  1965      7.671
# 2      Afghanistan  1966      7.671
# 3      Afghanistan  1967      7.671
# 4      Afghanistan  1968      7.671
# 5      Afghanistan  1969      7.671
# 6      Afghanistan  1970      7.671
# 7      Afghanistan  1971      7.671
# 8      Afghanistan  1972      7.671
# 9      Afghanistan  1973      7.671
# 10     Afghanistan  1974      7.671
# 11     Afghanistan  1975      7.671
# 12     Afghanistan  1976      7.670
# 13     Afghanistan  1977      7.670
# 14     Afghanistan  1978      7.670
# 15     Afghanistan  1979      7.669
# 16     Afghanistan  1980      7.669
# 17     Afghanistan  1981      7.670
# 18     Afghanistan  1982      7.671
# 19     Afghanistan  1983      7.673
# 20     Afghanistan  1984      7.676
# 21     Afghanistan  1985      7.679
# 22     Afghanistan  1986      7.681
# 23     Afghanistan  1987      7.682
# 24     Afghanistan  1988      7.682
# ...

# %% [markdown]
# ### Accessing row by row numbers #iloc

# %%
#### The iloc indexer syntax is data.iloc[<row selection>, <column selection>]

# %%
df.iloc[2] # 3rd row
# Out:
# Country            Afghanistan
# Year                      1966
# fertility                7.671
# life                    34.662
# population         1.09277e+07
# child_mortality          328.7
# gdp                       1168
# region              South Asia
# Name: 2, dtype: object

# %%
df.iloc[-1] # last row
# Out:
# Country                            Åland
# Year                                2006
# fertility                            NaN
# life                                80.1
# population                         26923
# child_mortality                      NaN
# gdp                                  NaN
# region             Europe & Central Asia
# Name: 10110, dtype: object

# %%
df.iloc[:,2] #Second column
# Out:
# 0        7.671
# 1        7.671
# 2        7.671
# 3        7.671
# 4        7.671
# 5        7.671
# 6        7.671
# 7        7.671
# 8        7.671
# 9        7.671
# 10       7.671
# 11       7.671
# 12       7.670
# 13       7.670
# 14       7.670
# 15       7.669
# 16       7.669
# 17       7.670
# 18       7.671
# 19       7.673
# 20       7.676
# 21       7.679
# 22       7.681
# 23       7.682
# 24       7.682
# 25       7.682
# 26       7.687
# 27       7.700
# 28       7.725
# 29       7.758
#          ...
# 10081    4.554
# 10082    4.432
# 10083    4.328
# 10084    4.240
# 10085    4.169
# 10086    4.112
# 10087    4.069
# 10088    4.039
# 10089    4.018
# 10090    4.002
# 10091    3.987
# 10092    3.969
# 10093    3.941
# 10094    3.903
# 10095    3.853
# 10096    3.792
# 10097    3.721
# 10098    3.643
# 10099    3.564
# 10100    3.486
# 10101      NaN
# 10102      NaN
# 10103      NaN
# 10104      NaN
# 10105      NaN
# 10106      NaN
# 10107      NaN
# ...

# %% [markdown]
# ### Selective few from a column

# %%
df.iloc[2:5,2] #Second column
# Out:
# 2    7.671
# 3    7.671
# 4    7.671
# Name: fertility, dtype: float64

# %% [markdown]
# ## Multiple columns and row can be selected together using the iloc indexer

# %%
# first five rows of dataframe
df.iloc[0:5]
# Out:
#        Country  Year  fertility    life  population  child_mortality     gdp  \
# 0  Afghanistan  1964      7.671  33.639  10474903.0            339.7  1182.0
# 1  Afghanistan  1965      7.671  34.152  10697983.0            334.1  1182.0
# 2  Afghanistan  1966      7.671  34.662  10927724.0            328.7  1168.0
# 3  Afghanistan  1967      7.671  35.170  11163656.0            323.3  1173.0
# 4  Afghanistan  1968      7.671  35.674  11411022.0            318.1  1187.0
#
#        region
# 0  South Asia
# 1  South Asia
# 2  South Asia
# 3  South Asia
# 4  South Asia

# %%
 # first two columns of data frame with all rows
df.iloc[:, 0:2]
# Out:
#            Country  Year
# 0      Afghanistan  1964
# 1      Afghanistan  1965
# 2      Afghanistan  1966
# 3      Afghanistan  1967
# 4      Afghanistan  1968
# 5      Afghanistan  1969
# 6      Afghanistan  1970
# 7      Afghanistan  1971
# 8      Afghanistan  1972
# 9      Afghanistan  1973
# 10     Afghanistan  1974
# 11     Afghanistan  1975
# 12     Afghanistan  1976
# 13     Afghanistan  1977
# 14     Afghanistan  1978
# 15     Afghanistan  1979
# 16     Afghanistan  1980
# 17     Afghanistan  1981
# 18     Afghanistan  1982
# 19     Afghanistan  1983
# 20     Afghanistan  1984
# 21     Afghanistan  1985
# 22     Afghanistan  1986
# 23     Afghanistan  1987
# 24     Afghanistan  1988
# 25     Afghanistan  1989
# 26     Afghanistan  1990
# 27     Afghanistan  1991
# 28     Afghanistan  1992
# 29     Afghanistan  1993
# ...            ...   ...
# 10081     Zimbabwe  1994
# 10082     Zimbabwe  1995
# 10083     Zimbabwe  1996
# 10084     Zimbabwe  1997
# 10085     Zimbabwe  1998
# ...

# %% [markdown]
# ### Selected few columns and rows

# %%
df.iloc[[0,3,6,24], [0,5,6]]
# Out:
#         Country  child_mortality     gdp
# 0   Afghanistan            339.7  1182.0
# 3   Afghanistan            323.3  1173.0
# 6   Afghanistan            307.8  1174.0
# 24  Afghanistan            195.0  1113.0

# %%
df.iloc[0:5, 5:8]
# Out:
#    child_mortality     gdp      region
# 0            339.7  1182.0  South Asia
# 1            334.1  1182.0  South Asia
# 2            328.7  1168.0  South Asia
# 3            323.3  1173.0  South Asia
# 4            318.1  1187.0  South Asia

# %% [markdown]
# ## Label-based /Index based indexing using .loc

# %%
fifa_19=pd.read_csv('/home/sachin/AthenasOwl/MachineLearningUtils/MachineLearningUtils/Data/csvs/fifa19.csv')

# %%
fifa_19.set_index('Name',inplace=True)
fifa_19=fifa_19.drop(['Unnamed: 0'],axis=1)

# %%
fifa_19.head(5)
# Out:
#                        ID  Age  \
# Name
# L. Messi           158023   31
# Cristiano Ronaldo   20801   33
# Neymar Jr          190871   26
# De Gea             193080   27
# K. De Bruyne       192985   27
#
#                                                             Photo Nationality  \
# Name
# L. Messi           https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# Cristiano Ronaldo   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# Neymar Jr          https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# De Gea             https://cdn.sofifa.org/players/4/19/193080.png       Spain
# K. De Bruyne       https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                                   Flag  Overall  Potential  \
# Name
# L. Messi           https://cdn.sofifa.org/flags/52.png       94         94
# Cristiano Ronaldo  https://cdn.sofifa.org/flags/38.png       94         94
# ...

# %% [markdown]
# ### Selecting data by label or by conditional statement

# %%
fifa_19.loc[['L. Messi']]
# Out:
#               ID  Age                                           Photo  \
# Name
# L. Messi  158023   31  https://cdn.sofifa.org/players/4/19/158023.png
#
#          Nationality                                 Flag  Overall  Potential  \
# Name
# L. Messi   Argentina  https://cdn.sofifa.org/flags/52.png       94         94
#
#                   Club                                     Club Logo    Value  \
# Name
# L. Messi  FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png  €110.5M
#
#               ...       Composure  Marking StandingTackle  SlidingTackle  \
# Name          ...
# L. Messi      ...            96.0     33.0           28.0           26.0
#
#           GKDiving  GKHandling GKKicking GKPositioning GKReflexes  \
# Name
# L. Messi       6.0        11.0      15.0          14.0        8.0
#
#          Release Clause
# Name
# L. Messi        €226.5M
#
# [1 rows x 87 columns]

# %%
#For multiple rows
fifa_19.loc[['L. Messi','Cristiano Ronaldo']]
# Out:
#                        ID  Age  \
# Name
# L. Messi           158023   31
# Cristiano Ronaldo   20801   33
#
#                                                             Photo Nationality  \
# Name
# L. Messi           https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# Cristiano Ronaldo   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
#
#                                                   Flag  Overall  Potential  \
# Name
# L. Messi           https://cdn.sofifa.org/flags/52.png       94         94
# Cristiano Ronaldo  https://cdn.sofifa.org/flags/38.png       94         94
#
#                            Club                                     Club Logo  \
# Name
# L. Messi           FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png
# Cristiano Ronaldo      Juventus   https://cdn.sofifa.org/teams/2/light/45.png
#
#                      Value      ...       Composure  Marking StandingTackle  \
# Name                            ...
# ...

# %% [markdown]
# ## Selecting multiple row and limited columns

# %%
fifa_19.loc[['L. Messi','Cristiano Ronaldo','Neymar Jr'],['Age','Club','Nationality']]
# Out:
#                    Age                 Club Nationality
# Name
# L. Messi            31         FC Barcelona   Argentina
# Cristiano Ronaldo   33             Juventus    Portugal
# Neymar Jr           26  Paris Saint-Germain      Brazil

# %% [markdown]
# ## Operations related to index

# %%
df['new_column']=np.arange(df.shape[0])*2

# %%
df.head(4)
# Out:
#        Country  Year  fertility    life  population  child_mortality     gdp  \
# 0  Afghanistan  1964      7.671  33.639  10474903.0            339.7  1182.0
# 1  Afghanistan  1965      7.671  34.152  10697983.0            334.1  1182.0
# 2  Afghanistan  1966      7.671  34.662  10927724.0            328.7  1168.0
# 3  Afghanistan  1967      7.671  35.170  11163656.0            323.3  1173.0
#
#        region  new_column
# 0  South Asia           0
# 1  South Asia           2
# 2  South Asia           4
# 3  South Asia           6

# %% [markdown]
# ### Setting index from columns

# %%
df.set_index("new_column", inplace=True)

# %%
df.head()
# Out:
#                 Country  Year  fertility    life  population  child_mortality  \
# new_column
# 0           Afghanistan  1964      7.671  33.639  10474903.0            339.7
# 2           Afghanistan  1965      7.671  34.152  10697983.0            334.1
# 4           Afghanistan  1966      7.671  34.662  10927724.0            328.7
# 6           Afghanistan  1967      7.671  35.170  11163656.0            323.3
# 8           Afghanistan  1968      7.671  35.674  11411022.0            318.1
#
#                gdp      region
# new_column
# 0           1182.0  South Asia
# 2           1182.0  South Asia
# 4           1168.0  South Asia
# 6           1173.0  South Asia
# 8           1187.0  South Asia

# %% [markdown]
# ### Resetting index

# %%
df.reset_index(drop=True, inplace=False)
# Out:
#            Country  Year  fertility    life  population  child_mortality  \
# 0      Afghanistan  1964      7.671  33.639  10474903.0            339.7
# 1      Afghanistan  1965      7.671  34.152  10697983.0            334.1
# 2      Afghanistan  1966      7.671  34.662  10927724.0            328.7
# 3      Afghanistan  1967      7.671  35.170  11163656.0            323.3
# 4      Afghanistan  1968      7.671  35.674  11411022.0            318.1
# 5      Afghanistan  1969      7.671  36.172  11676990.0            313.0
# 6      Afghanistan  1970      7.671  36.663  11964906.0            307.8
# 7      Afghanistan  1971      7.671  37.143  12273101.0            302.1
# 8      Afghanistan  1972      7.671  37.614  12593688.0            296.4
# 9      Afghanistan  1973      7.671  38.075  12915499.0            290.8
# 10     Afghanistan  1974      7.671  38.529  13223928.0            284.9
# 11     Afghanistan  1975      7.671  38.977  13505544.0            279.4
# ...

# %% [markdown]
# ### Adding rows to data frame

# %%
row_df=
df=df.append(row_df)
# Out:
#   File "<ipython-input-33-9dd0411eb753>", line 1
#     row_df=
#            ^
# SyntaxError: invalid syntax
